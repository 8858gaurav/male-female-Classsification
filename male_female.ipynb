# %%
from nltk.corpus import names
from nltk import NaiveBayesClassifier as NBC
from nltk import classify
import random, nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('vader_lexicon')
nltk.download('names')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# ...

# %%
def gender_features(word):
    return{'lastletter' : word[-1]}

# %%
maleNames = [(name,'male') for name in names.words('male.txt') ]
femaleNames = [(name, 'female') for name in names.words('female.txt')]

# %%
allNames = maleNames + femaleNames
random.shuffle(allNames)

# %%
featureData = [ (gender_features(namelist), gender) for (namelist, gender) in allNames ]
test_data = featureData[:700]
train_data = featureData[700:]

# %%
from nltk.corpus import names
from nltk import NaiveBayesClassifier as NBC
from nltk import classify
import random

# %%
classifier = NBC.train(train_data)

# %%
print(classifier.classify(gender_features('John Wick')))
print(classifier.classify(gender_features('Alexa')))
print(classifier.classify(gender_features('Abhishek')))
print(classifier.classify(gender_features('Renu')))
print(classifier.classify(gender_features('Sunita')))
print(classifier.classify(gender_features('Gaurav Mishra')))
print(classifier.classify(gender_features('Shivam')))
print(classifier.classify(gender_features('Nitin')))
print(classifier.classify(gender_features('Anubhav')))
print(classifier.classify(gender_features('Manpreet')))
print(classifier.classify(gender_features('Dimple')))
# Out:
# male
# female
# male
# male
# female
# female
# male
# male
# male
# male
# female

# %%
import pandas as pd
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
data_1 = pd.read_excel('/Users/HP/Downloads/kubric.io_women_ner.xlsx')
# data_1
lst = [x for x in data_1.NAME if x not in stop_words] 
lst = [x.replace('\n', ' ') for x in lst]
lst = [x.replace('\xa0', ' ') for x in lst]
# l=[x.split()[0] for x in lst]
lst
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-88ce1df2b916> in <module>
#       3
#       4 stop_words = stopwords.words('english')
# ----> 5 data_1 = pd.read_excel('/Users/HP/Downloads/kubric.io_women_ner.xlsx')
#       6 # data_1
#       7 lst = [x for x in data_1.NAME if x not in stop_words]
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
# import pandas as pd
# data1=pd.read_excel('/Users/HP/Documents/Book1_name.xlsx')
# data1

# %%
m = []
for i in lst:
    if classifier.classify(gender_features(i))=='female':
        m.append(i)

# %%
m
# Out:
# ['  ',
#  'SunnyBee  ',
#  'HORECA',
#  'Madan Padaki',
#  'Geetha Ramamurthy',
#  'Suryanarayanan A',
#  'Naganand Doraswamy',
#  'Jawahar Bekay',
#  'Vijetha Shastry',
#  'Nandan Nilekani',
#  'Sridhar Mitta',
#  'MSME Sambandh',
#  'FY19',
#  '  ',
#  'AYUSH',
#  '—',
#  'Bumble',
#  'Arya Vaidya Pharmacy',
#  'Ayush',
#  'Preethika Balaji',
#  'Annapurna',
#  'Sneha Dwivedi',
#  'Dwivedi',
#  'Aruna Katragadda',
#  'Aruna',
#  'Shruti Sancheti',
#  'Neeta Lulla',
#  'Ambika PillaiBe',
#  'Ambika Pillai',
#  'Protima Tiwary',
#  'Protima',
#  '@dumbbellsndrama ',
#  'Moushmi',
#  'Zaveri Sanas ',
#  'Zainab Jariwala',
#  'M. Gurumoorthy',
#  'Lok Sabha',
#  'Panabaka Lakshmi',
#  'Chinta',
#  'Swathi Malagi',
#  'Rakesh Reddy',
#  'Karnataka K. Ratna Prabha',
#  'Narendra Modi',
#  'Ratna Prabha',
#  'M. Chakravarthy',
#  'Megan Rapinoe',
#  'Rapinoe',
#  'Anupa Mehta',
#  '    ',
#  'yourself’',
#  'Roy',
#  'Strike',
#  'Youtube',
#  'Kukatpally',
#  'Nirbhaya',
# ...

# %%
data_1 = pd.DataFrame({'Name':m})

# %%
data_1.to_excel('/Users/HP/Downloads/Women_name.xlsx')
